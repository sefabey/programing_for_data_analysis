# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/sefaozalp'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/sefaozalp/Documents/Work/teaching/cardiff_met/prog_for_data_analysis/notebooks/week1/phone_data.csv')

# %%
df.dtypes
# Out:
# index         int64
# date         object
# duration    float64
# item         object
# month        object
# network      object
# dtype: object

# %%
df['duration'].describe()
# Out:
# count      828.000000
# mean       118.086171
# std        444.629082
# min          1.000000
# 25%          1.000000
# 50%         25.000000
# 75%         55.250000
# max      10528.000000
# Name: duration, dtype: float64

# %%
df['duration'].plot()

# %%
df.loc[df['duration'] > 2000] # note the usage of loc
# Out:
#      index              date  duration  item    month network
# 252    252  19/11/2014 18:56    2120.0  call  2014-12   Three
# 742    742  17/02/2015 19:09    2328.0  call  2015-03   Three
# 816    816  04/03/2015 12:29   10528.0  call  2015-03   Tesco

# %% [markdown]
# TASK: Change the value to different min thresholds e.g. 1500, 1000 etc. and set a cut off value say 600 min

# %%
filter_df = df.drop(df[df['duration'] > 600].index) # drop records 600+ min duration
filter_df
# Out:
#      index              date  duration  item    month   network
# 0        0  15/10/2014 06:58    34.429  data  2014-11     Tesco
# 1        1  15/10/2014 06:58    13.000   NaN  2014-11  Vodafone
# 2        2  15/10/2014 14:46    23.000  call  2014-11     Meter
# 3        3  15/10/2014 14:48     4.000  call  2014-11     Tesco
# 4        4  15/10/2014 17:27     4.000  call  2014-11   Tescoss
# ..     ...               ...       ...   ...      ...       ...
# 825    825  13/03/2015 00:38     1.000   sms  2015-03     world
# 826    826  13/03/2015 00:39     1.000   sms  2015-03  Vodafone
# 827    827  13/03/2015 06:58    34.429  data  2015-03     Tesco
# 828    828  14/03/2015 00:13     1.000   sms  2015-03     world
# 829    829  14/03/2015 00:16     1.000   sms  2015-03     world
#
# [790 rows x 6 columns]

# %% [markdown]
# ## lets unpack what just happened here

# %%
df['duration']
# Out:
# 0      34.429
# 1      13.000
# 2      23.000
# 3       4.000
# 4       4.000
#         ...
# 825     1.000
# 826     1.000
# 827    34.429
# 828     1.000
# 829     1.000
# Name: duration, Length: 830, dtype: float64

# %%
df['duration'] > 600
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 825    False
# 826    False
# 827    False
# 828    False
# 829    False
# Name: duration, Length: 830, dtype: bool

# %%
df[df['duration'] > 600]
# Out:
#      index              date  duration  item    month   network
# 7        7  16/10/2014 15:01     602.0  call  2014-11     Three
# 8        8  16/10/2014 15:12    1050.0  call  2014-11     Three
# 10      10  16/10/2014 16:21    1183.0  call  2014-11     Three
# 27      27  18/10/2014 11:51     783.0  call  2014-11     Tesco
# 31      31  18/10/2014 13:10    1714.0  call  2014-11     Three
# 59      59  23/10/2014 08:34    1940.0  call  2014-11     Tesco
# 83      83  26/10/2014 21:10     637.0  call  2014-11     Tesco
# 90      90  27/10/2014 19:20     862.0  call  2014-11     Three
# 93      93  28/10/2014 16:39     833.0  call  2014-11     Tesco
# 105    105  31/10/2014 13:27    1234.0  call  2014-11     Tesco
# 112    112  01/11/2014 15:13     955.0  call  2014-11  Vodafone
# 116    116  02/11/2014 15:44    1023.0  call  2014-11     Three
# 117    117  02/11/2014 19:16    1025.0  call  2014-11     Three
# 171    171  07/11/2014 09:33    1205.0  call  2014-11  Vodafone
# ...

# %%
df[df['duration'] > 600].index
# Out:
# Int64Index([  7,   8,  10,  27,  31,  59,  83,  90,  93, 105, 112, 116, 117,
#             171, 223, 252, 268, 322, 344, 354, 367, 398, 441, 506, 526, 528,
#             548, 615, 631, 632, 636, 648, 709, 718, 719, 742, 807, 809, 810,
#             816],
#            dtype='int64')

# %%
df.drop(df[df['duration'] > 600].index)
# Out:
#      index              date  duration  item    month   network
# 0        0  15/10/2014 06:58    34.429  data  2014-11     Tesco
# 1        1  15/10/2014 06:58    13.000   NaN  2014-11  Vodafone
# 2        2  15/10/2014 14:46    23.000  call  2014-11     Meter
# 3        3  15/10/2014 14:48     4.000  call  2014-11     Tesco
# 4        4  15/10/2014 17:27     4.000  call  2014-11   Tescoss
# ..     ...               ...       ...   ...      ...       ...
# 825    825  13/03/2015 00:38     1.000   sms  2015-03     world
# 826    826  13/03/2015 00:39     1.000   sms  2015-03  Vodafone
# 827    827  13/03/2015 06:58    34.429  data  2015-03     Tesco
# 828    828  14/03/2015 00:13     1.000   sms  2015-03     world
# 829    829  14/03/2015 00:16     1.000   sms  2015-03     world
#
# [790 rows x 6 columns]

# %% [markdown]
# if you want to create a dataframe for certain range (records where duration is between 5 to 10 min)

# %%
filter2_df = df[ (df['duration']>=5) & (df['duration']<=10) ]

# %% [markdown]
# ### ALMOST NEVER DO THIS:
# "Remember if you use inplace=True then you don’t need to assign to a new dataframe "

# %%
filter_df.dtypes
# Out:
# index         int64
# date         object
# duration    float64
# item         object
# month        object
# network      object
# dtype: object

# %%
filter_df['duration'].hist(bins=50)

# %%
df['network'].value_counts()
# Out:
# Tesco       301
# Vodafone    215
# Three       215
# Meteor       86
# world         7
# special       3
# Tescoss       1
# Tescos        1
# Meter         1
# Name: network, dtype: int64

# %%
#df['network'].replace(['Tescos', 'Tescoss'], 'Tesco', inplace=True)
df['network_clean'] = df['network'].replace(['Tescos', 'Tescoss'], 'Tesco')

# %%
df['network_clean'].value_counts()
# Out:
# Tesco       303
# Vodafone    215
# Three       215
# Meteor       86
# world         7
# special       3
# Meter         1
# Name: network_clean, dtype: int64

# %%
df['network'].value_counts()
# Out:
# Tesco       301
# Vodafone    215
# Three       215
# Meteor       86
# world         7
# special       3
# Tescoss       1
# Tescos        1
# Meter         1
# Name: network, dtype: int64

# %% [markdown]
# ## TASK: Do the same for Meteor

# %%
df['network_clean'] = df['network_clean'].replace(['Meter'], 'Meteor')
df['network_clean'].value_counts()
# Out:
# Tesco       303
# Vodafone    215
# Three       215
# Meteor       87
# world         7
# special       3
# Name: network_clean, dtype: int64

# %%
filter_df.to_csv("Documents/Work/teaching/cardiff_met/prog_for_data_analysis/notebooks/week2/filtered_phone_data.csv")

# %% [markdown]
# # Select

# %%
df.loc[df['column_name'] == some_value]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'column_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-cbc6a5d8c61b> in <module>()
# ...

# %%
df.loc[df['network'] == 'Tesco']
# Out:
#      index              date  duration  item    month network network_clean
# 0        0  15/10/2014 06:58    34.429  data  2014-11   Tesco         Tesco
# 3        3  15/10/2014 14:48     4.000  call  2014-11   Tesco         Tesco
# 5        5  15/10/2014 18:55     4.000  call  2014-11   Tesco         Tesco
# 6        6  16/10/2014 06:58    34.429  data  2014-11   Tesco         Tesco
# 9        9  16/10/2014 15:30    19.000  call  2014-11   Tesco         Tesco
# ..     ...               ...       ...   ...      ...     ...           ...
# 821    821  09/03/2015 06:58    34.429  data  2015-03   Tesco         Tesco
# 822    822  10/03/2015 06:58    34.429  data  2015-03   Tesco         Tesco
# 823    823  11/03/2015 06:58    34.429  data  2015-03   Tesco         Tesco
# 824    824  12/03/2015 06:58    34.429  data  2015-03   Tesco         Tesco
# 827    827  13/03/2015 06:58    34.429  data  2015-03   Tesco         Tesco
#
# [301 rows x 7 columns]

# %% [markdown]
# ## TASK: find rows where  ‘item’ is ‘call’

# %%
df.loc[df['item'] == 'call']
# Out:
#      index              date  duration  item    month   network network_clean
# 2        2  15/10/2014 14:46      23.0  call  2014-11     Meter        Meteor
# 3        3  15/10/2014 14:48       4.0  call  2014-11     Tesco         Tesco
# 4        4  15/10/2014 17:27       4.0  call  2014-11   Tescoss         Tesco
# 5        5  15/10/2014 18:55       4.0  call  2014-11     Tesco         Tesco
# 7        7  16/10/2014 15:01     602.0  call  2014-11     Three         Three
# ..     ...               ...       ...   ...      ...       ...           ...
# 807    807  03/03/2015 10:12     745.0  call  2015-03  Vodafone      Vodafone
# 808    808  03/03/2015 10:27      57.0  call  2015-03  Vodafone      Vodafone
# 809    809  03/03/2015 14:34    1325.0  call  2015-03  Vodafone      Vodafone
# 810    810  03/03/2015 18:36     768.0  call  2015-03     Three         Three
# 816    816  04/03/2015 12:29   10528.0  call  2015-03     Tesco         Tesco
#
# [387 rows x 7 columns]

# %% [markdown]
# ## TASK: find rows where item is call & duration is less than 10 min!

# %%
df.loc[ (df['item'] == 'call') & (df['duration']<10) ]
# Out:
#      index              date  duration  item    month   network network_clean
# 3        3  15/10/2014 14:48       4.0  call  2014-11     Tesco         Tesco
# 4        4  15/10/2014 17:27       4.0  call  2014-11   Tescoss         Tesco
# 5        5  15/10/2014 18:55       4.0  call  2014-11     Tesco         Tesco
# 20      20  17/10/2014 17:29       4.0  call  2014-11  Vodafone      Vodafone
# 28      28  18/10/2014 12:06       4.0  call  2014-11  Vodafone      Vodafone
# ..     ...               ...       ...   ...      ...       ...           ...
# 733    733  13/02/2015 21:13       8.0  call  2015-03  Vodafone      Vodafone
# 782    782  28/02/2015 15:09       5.0  call  2015-03     Three         Three
# 786    786  28/02/2015 17:14       3.0  call  2015-03     Tesco         Tesco
# 792    792  01/03/2015 12:19       9.0  call  2015-03    Meteor        Meteor
# 800    800  02/03/2015 14:53       2.0  call  2015-03     Tesco         Tesco
#
# [88 rows x 7 columns]

# %% [markdown]
# # String Search

# %%
df[df['network'].str.match('Tes')]
# Out:
#      index              date  duration  item    month  network network_clean
# 0        0  15/10/2014 06:58    34.429  data  2014-11    Tesco         Tesco
# 3        3  15/10/2014 14:48     4.000  call  2014-11    Tesco         Tesco
# 4        4  15/10/2014 17:27     4.000  call  2014-11  Tescoss         Tesco
# 5        5  15/10/2014 18:55     4.000  call  2014-11    Tesco         Tesco
# 6        6  16/10/2014 06:58    34.429  data  2014-11    Tesco         Tesco
# ..     ...               ...       ...   ...      ...      ...           ...
# 821    821  09/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
# 822    822  10/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
# 823    823  11/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
# 824    824  12/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
# 827    827  13/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
#
# [303 rows x 7 columns]

# %%
df[df['network'].str.match('esc')]
# Out:
# Empty DataFrame
# Columns: [index, date, duration, item, month, network, network_clean]
# Index: []

# %%
df[df['network'].str.contains('esc')]
# Out:
#      index              date  duration  item    month  network network_clean
# 0        0  15/10/2014 06:58    34.429  data  2014-11    Tesco         Tesco
# 3        3  15/10/2014 14:48     4.000  call  2014-11    Tesco         Tesco
# 4        4  15/10/2014 17:27     4.000  call  2014-11  Tescoss         Tesco
# 5        5  15/10/2014 18:55     4.000  call  2014-11    Tesco         Tesco
# 6        6  16/10/2014 06:58    34.429  data  2014-11    Tesco         Tesco
# ..     ...               ...       ...   ...      ...      ...           ...
# 821    821  09/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
# 822    822  10/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
# 823    823  11/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
# 824    824  12/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
# 827    827  13/03/2015 06:58    34.429  data  2015-03    Tesco         Tesco
#
# [303 rows x 7 columns]

# %% [markdown]
# ## TASK: find rows/records where network contains ‘ne’ and the item is sms !

# %%
df[df['network'].str.contains('ne')]
# Out:
#      index              date  duration  item    month   network network_clean
# 1        1  15/10/2014 06:58      13.0   NaN  2014-11  Vodafone      Vodafone
# 17      17  17/10/2014 17:22       1.0   sms  2014-11  Vodafone      Vodafone
# 18      18  17/10/2014 17:23       NaN   sms  2014-11  Vodafone      Vodafone
# 20      20  17/10/2014 17:29       4.0  call  2014-11  Vodafone      Vodafone
# 22      22  17/10/2014 17:42       1.0   sms  2014-11  Vodafone      Vodafone
# ..     ...               ...       ...   ...      ...       ...           ...
# 808    808  03/03/2015 10:27      57.0  call  2015-03  Vodafone      Vodafone
# 809    809  03/03/2015 14:34    1325.0  call  2015-03  Vodafone      Vodafone
# 812    812  04/03/2015 07:02       1.0   sms  2015-03  Vodafone      Vodafone
# 813    813  04/03/2015 07:16       1.0   sms  2015-03  Vodafone      Vodafone
# 826    826  13/03/2015 00:39       1.0   sms  2015-03  Vodafone      Vodafone
#
# [215 rows x 7 columns]

# %%
df[ (df['network'].str.contains('ne')) & (df['item']=="sms") ]
# Out:
#      index              date  duration item    month   network network_clean
# 17      17  17/10/2014 17:22       1.0  sms  2014-11  Vodafone      Vodafone
# 18      18  17/10/2014 17:23       NaN  sms  2014-11  Vodafone      Vodafone
# 22      22  17/10/2014 17:42       1.0  sms  2014-11  Vodafone      Vodafone
# 23      23  17/10/2014 17:44       1.0  sms  2014-11  Vodafone      Vodafone
# 24      24  17/10/2014 17:44       1.0  sms  2014-11  Vodafone      Vodafone
# ..     ...               ...       ...  ...      ...       ...           ...
# 797    797  02/03/2015 09:30       1.0  sms  2015-03  Vodafone      Vodafone
# 798    798  02/03/2015 09:30       1.0  sms  2015-03  Vodafone      Vodafone
# 812    812  04/03/2015 07:02       1.0  sms  2015-03  Vodafone      Vodafone
# 813    813  04/03/2015 07:16       1.0  sms  2015-03  Vodafone      Vodafone
# 826    826  13/03/2015 00:39       1.0  sms  2015-03  Vodafone      Vodafone
#
# [149 rows x 7 columns]

# %% [markdown]
# # Sort

# %%
df.sort_values('duration')  # Ascending order
# Out:
#      index              date  duration  item    month   network network_clean
# 829    829  14/03/2015 00:16       1.0   sms  2015-03     world         world
# 317    317  26/11/2014 11:54       1.0   sms  2014-12    Meteor        Meteor
# 316    316  26/11/2014 11:53       1.0   sms  2014-12    Meteor        Meteor
# 315    315  26/11/2014 09:01       1.0   sms  2014-12    Meteor        Meteor
# 310    310  26/11/2014 08:00       1.0   sms  2014-12  Vodafone      Vodafone
# ..     ...               ...       ...   ...      ...       ...           ...
# 252    252  19/11/2014 18:56    2120.0  call  2014-12     Three         Three
# 742    742  17/02/2015 19:09    2328.0  call  2015-03     Three         Three
# 816    816  04/03/2015 12:29   10528.0  call  2015-03     Tesco         Tesco
# 11      11  16/10/2014 22:18       NaN   sms  2014-11    Meteor        Meteor
# 18      18  17/10/2014 17:23       NaN   sms  2014-11  Vodafone      Vodafone
#
# [830 rows x 7 columns]

# %%
df.sort_values('date', ascending=False)
# Out:
#      index              date  duration  item    month   network network_clean
# 503    503  31/12/2014 23:37     1.000   sms  2015-01  Vodafone      Vodafone
# 502    502  31/12/2014 23:37     1.000   sms  2015-01  Vodafone      Vodafone
# 501    501  31/12/2014 23:37     1.000   sms  2015-01  Vodafone      Vodafone
# 500    500  31/12/2014 23:05     1.000   sms  2015-01  Vodafone      Vodafone
# 499    499  31/12/2014 13:49   526.000  call  2015-01     Tesco         Tesco
# ..     ...               ...       ...   ...      ...       ...           ...
# 792    792  01/03/2015 12:19     9.000  call  2015-03    Meteor        Meteor
# 791    791  01/03/2015 06:58    34.429  data  2015-03     Tesco         Tesco
# 674    674  01/02/2015 13:33   103.000  call  2015-02     Tesco         Tesco
# 673    673  01/02/2015 06:58    34.429  data  2015-02     Tesco         Tesco
# 504    504  01/01/2015 06:58    34.429  data  2015-01     Tesco         Tesco
#
# [830 rows x 7 columns]

# %% [markdown]
# ## TASK: Sort the call duration of records where network contains the substring ‘esc’ .  ** previous command returns a dataframe, can you join the sort command after that**

# %%
df[df['network'].str.contains('esc')].sort_values('date')
# Out:
#      index              date  duration  item    month network network_clean
# 504    504  01/01/2015 06:58    34.429  data  2015-01   Tesco         Tesco
# 673    673  01/02/2015 06:58    34.429  data  2015-02   Tesco         Tesco
# 674    674  01/02/2015 13:33   103.000  call  2015-02   Tesco         Tesco
# 791    791  01/03/2015 06:58    34.429  data  2015-03   Tesco         Tesco
# 111    111  01/11/2014 06:58    34.429  data  2014-11   Tesco         Tesco
# ..     ...               ...       ...   ...      ...     ...           ...
# 101    101  31/10/2014 06:58    34.429  data  2014-11   Tesco         Tesco
# 105    105  31/10/2014 13:27  1234.000  call  2014-11   Tesco         Tesco
# 110    110  31/10/2014 18:39     3.000  call  2014-11   Tesco         Tesco
# 496    496  31/12/2014 06:58    34.429  data  2015-01   Tesco         Tesco
# 499    499  31/12/2014 13:49   526.000  call  2015-01   Tesco         Tesco
#
# [303 rows x 7 columns]
